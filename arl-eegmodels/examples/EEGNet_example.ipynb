# %%
"""
 Sample script using EEGNet to classify Event-Related Potential (ERP) EEG data
 from a four-class classification task, using the sample dataset provided in
 the MNE [1, 2] package:
     https://martinos.org/mne/stable/manual/sample_dataset.html#ch-sample-data
   
 The four classes used from this dataset are:
     LA: Left-ear auditory stimulation
     RA: Right-ear auditory stimulation
     LV: Left visual field stimulation
     RV: Right visual field stimulation

 The code to process, filter and epoch the data are originally from Alexandre
 Barachant's PyRiemann [3] package, released under the BSD 3-clause. A copy of 
 the BSD 3-clause license has been provided together with this software to 
 comply with software licensing requirements. 
 
 When you first run this script, MNE will download the dataset and prompt you
 to confirm the download location (defaults to ~/mne_data). Follow the prompts
 to continue. The dataset size is approx. 1.5GB download. 
 
 For comparative purposes you can also compare EEGNet performance to using 
 Riemannian geometric approaches with xDAWN spatial filtering [4-8] using 
 PyRiemann (code provided below).

 [1] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck,
     L. Parkkonen, M. Hämäläinen, MNE software for processing MEG and EEG data, 
     NeuroImage, Volume 86, 1 February 2014, Pages 446-460, ISSN 1053-8119.

 [2] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck, 
     R. Goj, M. Jas, T. Brooks, L. Parkkonen, M. Hämäläinen, MEG and EEG data 
     analysis with MNE-Python, Frontiers in Neuroscience, Volume 7, 2013.

 [3] https://github.com/alexandrebarachant/pyRiemann. 

 [4] A. Barachant, M. Congedo ,"A Plug&Play P300 BCI Using Information Geometry"
     arXiv:1409.0107. link

 [5] M. Congedo, A. Barachant, A. Andreev ,"A New generation of Brain-Computer 
     Interface Based on Riemannian Geometry", arXiv: 1310.8115.

 [6] A. Barachant and S. Bonnet, "Channel selection procedure using riemannian 
     distance for BCI applications," in 2011 5th International IEEE/EMBS 
     Conference on Neural Engineering (NER), 2011, 348-351.

 [7] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Multiclass 
     Brain-Computer Interface Classification by Riemannian Geometry,” in IEEE 
     Transactions on Biomedical Engineering, vol. 59, no. 4, p. 920-928, 2012.

 [8] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Classification of 
     covariance matrices using a Riemannian-based kernel for BCI applications“, 
     in NeuroComputing, vol. 112, p. 172-178, 2013.


 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""
# Out:
# '\n Sample script using EEGNet to classify Event-Related Potential (ERP) EEG data\n from a four-class classification task, using the sample dataset provided in\n the MNE [1, 2] package:\n     https://martinos.org/mne/stable/manual/sample_dataset.html#ch-sample-data\n   \n The four classes used from this dataset are:\n     LA: Left-ear auditory stimulation\n     RA: Right-ear auditory stimulation\n     LV: Left visual field stimulation\n     RV: Right visual field stimulation\n\n The code to process, filter and epoch the data are originally from Alexandre\n Barachant\'s PyRiemann [3] package, released under the BSD 3-clause. A copy of \n the BSD 3-clause license has been provided together with this software to \n comply with software licensing requirements. \n \n When you first run this script, MNE will download the dataset and prompt you\n to confirm the download location (defaults to ~/mne_data). Follow the prompts\n to continue. The dataset size is approx. 1.5GB download. \n \n For comparative purposes you can also compare EEGNet performance to using \n Riemannian geometric approaches with xDAWN spatial filtering [4-8] using \n PyRiemann (code provided below).\n\n [1] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck,\n     L. Parkkonen, M. Hämäläinen, MNE software for processing MEG and EEG data, \n     NeuroImage, Volume 86, 1 February 2014, Pages 446-460, ISSN 1053-8119.\n\n [2] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck, \n     R. Goj, M. Jas, T. Brooks, L. Parkkonen, M. Hämäläinen, MEG and EEG data \n     analysis with MNE-Python, Frontiers in Neuroscience, Volume 7, 2013.\n\n [3] https://github.com/alexandrebarachant/pyRiemann. \n\n [4] A. Barachant, M. Congedo ,"A Plug&Play P300 BCI Using Information Geometry"\n     arXiv:1409.0107. link\n\n [5] M. Congedo, A. Barachant, A. Andreev ,"A New generation of Brain-Computer \n     Interface Based on Riemannian Geometry", arXiv: 1310.8115.\n\n [6] A. Barachant and S. Bonnet, "Channel selection procedure using riemannian \n     distance for BCI applications," in 2011 5th International IEEE/EMBS \n     Conference on Neural Engineering (NER), 2011, 348-351.\n\n [7] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Multiclass \n     Brain-Computer Interface Classification by Riemannian Geometry,” in IEEE \n     Transactions on Biomedical Engineering, vol. 59, no. 4, p. 920-928, 2012.\n\n [8] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Classification of \n     covariance matrices using a Riemannian-based kernel for BCI applications“, \n     in NeuroComputing, vol. 112, p. 172-178, 2013.\n\n\n Portions of this project are works of the United States Government and are not\n subject to domestic copyright protection under 17 USC Sec. 105.  Those \n portions are released world-wide under the terms of the Creative Commons Zero \n 1.0 (CC0) license.  \n \n Other portions of this project are subject to domestic copyright protection \n under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 \n license.  The complete text of the license governing this material is in \n the file labeled LICENSE.TXT that is a part of this project\'s official \n distribution. \n'

# %%
import PyQt5
# %config InlineBackend.figure_format = 'retina'
# %matplotlib qt5

import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from pyriemann.utils.viz import plot_confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

# %%
##################### Process, filter and epoch the data ######################
data_path = sample.data_path()

# Set parameters and read data
raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 60, 151

# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

# %%
############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 4, Chans = chans, Samples = samples, 
               dropoutRate = 0.5, kernLength = 32, F1 = 8, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='checkpoint.h5', verbose=1,
                               save_best_only=True)
# Out:
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples

# %%
###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

# %%
################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)

# load optimal weights
# model.load_weights('/tmp/checkpoint.h5')
# Out:
# Epoch 1/300
#
# Epoch 00001: val_loss improved from inf to 1.38622, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.4198 - accuracy: 0.2431 - val_loss: 1.3862 - val_accuracy: 0.2639
# Epoch 2/300
#
# Epoch 00002: val_loss improved from 1.38622 to 1.38613, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3923 - accuracy: 0.2639 - val_loss: 1.3861 - val_accuracy: 0.2639
# Epoch 3/300
#
# Epoch 00003: val_loss improved from 1.38613 to 1.38609, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3787 - accuracy: 0.2917 - val_loss: 1.3861 - val_accuracy: 0.2639
# Epoch 4/300
#
# Epoch 00004: val_loss improved from 1.38609 to 1.38605, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3651 - accuracy: 0.3333 - val_loss: 1.3861 - val_accuracy: 0.2639
# Epoch 5/300
#
# Epoch 00005: val_loss improved from 1.38605 to 1.38602, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3569 - accuracy: 0.3958 - val_loss: 1.3860 - val_accuracy: 0.2639
# Epoch 6/300
#
# Epoch 00006: val_loss improved from 1.38602 to 1.38597, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3565 - accuracy: 0.3958 - val_loss: 1.3860 - val_accuracy: 0.2639
# Epoch 7/300
#
# Epoch 00007: val_loss improved from 1.38597 to 1.38591, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3444 - accuracy: 0.4167 - val_loss: 1.3859 - val_accuracy: 0.2639
# Epoch 8/300
#
# Epoch 00008: val_loss improved from 1.38591 to 1.38586, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3384 - accuracy: 0.4097 - val_loss: 1.3859 - val_accuracy: 0.2639
# Epoch 9/300
#
# Epoch 00009: val_loss improved from 1.38586 to 1.38579, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3247 - accuracy: 0.4861 - val_loss: 1.3858 - val_accuracy: 0.2639
# Epoch 10/300
#
# Epoch 00010: val_loss improved from 1.38579 to 1.38572, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3167 - accuracy: 0.4514 - val_loss: 1.3857 - val_accuracy: 0.2639
# Epoch 11/300
#
# Epoch 00011: val_loss improved from 1.38572 to 1.38562, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.3060 - accuracy: 0.4444 - val_loss: 1.3856 - val_accuracy: 0.2639
# Epoch 12/300
#
# Epoch 00012: val_loss improved from 1.38562 to 1.38549, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.2800 - accuracy: 0.5417 - val_loss: 1.3855 - val_accuracy: 0.2639
# Epoch 13/300
#
# Epoch 00013: val_loss improved from 1.38549 to 1.38528, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.2778 - accuracy: 0.4931 - val_loss: 1.3853 - val_accuracy: 0.2639
# Epoch 14/300
#
# Epoch 00014: val_loss improved from 1.38528 to 1.38504, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.2426 - accuracy: 0.4861 - val_loss: 1.3850 - val_accuracy: 0.2639
# Epoch 15/300
#
# Epoch 00015: val_loss improved from 1.38504 to 1.38465, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.2073 - accuracy: 0.5764 - val_loss: 1.3847 - val_accuracy: 0.2639
# Epoch 16/300
#
# Epoch 00016: val_loss improved from 1.38465 to 1.38417, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.1890 - accuracy: 0.5764 - val_loss: 1.3842 - val_accuracy: 0.2639
# Epoch 17/300
#
# Epoch 00017: val_loss improved from 1.38417 to 1.38368, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.1770 - accuracy: 0.5278 - val_loss: 1.3837 - val_accuracy: 0.2639
# Epoch 18/300
#
# Epoch 00018: val_loss improved from 1.38368 to 1.38307, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.1345 - accuracy: 0.5417 - val_loss: 1.3831 - val_accuracy: 0.2639
# Epoch 19/300
#
# Epoch 00019: val_loss improved from 1.38307 to 1.38221, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.1403 - accuracy: 0.5486 - val_loss: 1.3822 - val_accuracy: 0.2639
# Epoch 20/300
#
# Epoch 00020: val_loss improved from 1.38221 to 1.38144, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.1203 - accuracy: 0.5347 - val_loss: 1.3814 - val_accuracy: 0.2917
# Epoch 21/300
#
# Epoch 00021: val_loss improved from 1.38144 to 1.38020, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0960 - accuracy: 0.5694 - val_loss: 1.3802 - val_accuracy: 0.3194
# Epoch 22/300
#
# Epoch 00022: val_loss improved from 1.38020 to 1.37884, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0620 - accuracy: 0.5833 - val_loss: 1.3788 - val_accuracy: 0.3611
# Epoch 23/300
#
# Epoch 00023: val_loss improved from 1.37884 to 1.37756, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0364 - accuracy: 0.6250 - val_loss: 1.3776 - val_accuracy: 0.3611
# Epoch 24/300
#
# Epoch 00024: val_loss improved from 1.37756 to 1.37601, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0133 - accuracy: 0.5625 - val_loss: 1.3760 - val_accuracy: 0.3611
# Epoch 25/300
#
# Epoch 00025: val_loss improved from 1.37601 to 1.37433, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0082 - accuracy: 0.5556 - val_loss: 1.3743 - val_accuracy: 0.3750
# Epoch 26/300
#
# Epoch 00026: val_loss improved from 1.37433 to 1.37265, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0223 - accuracy: 0.5764 - val_loss: 1.3727 - val_accuracy: 0.3750
# Epoch 27/300
#
# Epoch 00027: val_loss improved from 1.37265 to 1.37053, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0336 - accuracy: 0.5625 - val_loss: 1.3705 - val_accuracy: 0.3750
# Epoch 28/300
#
# Epoch 00028: val_loss improved from 1.37053 to 1.36810, saving model to checkpoint.h5
# 9/9 - 0s - loss: 1.0108 - accuracy: 0.5833 - val_loss: 1.3681 - val_accuracy: 0.3750
# Epoch 29/300
#
# Epoch 00029: val_loss improved from 1.36810 to 1.36592, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9935 - accuracy: 0.5764 - val_loss: 1.3659 - val_accuracy: 0.3750
# Epoch 30/300
#
# Epoch 00030: val_loss improved from 1.36592 to 1.36350, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9653 - accuracy: 0.6111 - val_loss: 1.3635 - val_accuracy: 0.3750
# Epoch 31/300
#
# Epoch 00031: val_loss improved from 1.36350 to 1.36099, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9684 - accuracy: 0.5903 - val_loss: 1.3610 - val_accuracy: 0.3889
# Epoch 32/300
#
# Epoch 00032: val_loss improved from 1.36099 to 1.35854, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9744 - accuracy: 0.5069 - val_loss: 1.3585 - val_accuracy: 0.3889
# Epoch 33/300
#
# Epoch 00033: val_loss improved from 1.35854 to 1.35619, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9600 - accuracy: 0.6181 - val_loss: 1.3562 - val_accuracy: 0.3889
# Epoch 34/300
#
# Epoch 00034: val_loss improved from 1.35619 to 1.35322, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9555 - accuracy: 0.5833 - val_loss: 1.3532 - val_accuracy: 0.3750
# Epoch 35/300
#
# Epoch 00035: val_loss improved from 1.35322 to 1.34835, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9676 - accuracy: 0.6042 - val_loss: 1.3484 - val_accuracy: 0.3750
# Epoch 36/300
#
# Epoch 00036: val_loss improved from 1.34835 to 1.34522, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9590 - accuracy: 0.5486 - val_loss: 1.3452 - val_accuracy: 0.4028
# Epoch 37/300
#
# Epoch 00037: val_loss improved from 1.34522 to 1.34108, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9469 - accuracy: 0.5903 - val_loss: 1.3411 - val_accuracy: 0.3750
# Epoch 38/300
#
# Epoch 00038: val_loss improved from 1.34108 to 1.33795, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9330 - accuracy: 0.6528 - val_loss: 1.3379 - val_accuracy: 0.3750
# Epoch 39/300
#
# Epoch 00039: val_loss improved from 1.33795 to 1.33349, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9339 - accuracy: 0.6181 - val_loss: 1.3335 - val_accuracy: 0.4028
# Epoch 40/300
#
# Epoch 00040: val_loss improved from 1.33349 to 1.32911, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9242 - accuracy: 0.6042 - val_loss: 1.3291 - val_accuracy: 0.3889
# Epoch 41/300
#
# Epoch 00041: val_loss improved from 1.32911 to 1.32461, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9299 - accuracy: 0.6250 - val_loss: 1.3246 - val_accuracy: 0.4167
# Epoch 42/300
#
# Epoch 00042: val_loss improved from 1.32461 to 1.32198, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9250 - accuracy: 0.6389 - val_loss: 1.3220 - val_accuracy: 0.3889
# Epoch 43/300
#
# Epoch 00043: val_loss improved from 1.32198 to 1.31567, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9089 - accuracy: 0.6111 - val_loss: 1.3157 - val_accuracy: 0.3750
# Epoch 44/300
#
# Epoch 00044: val_loss improved from 1.31567 to 1.31023, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9234 - accuracy: 0.6250 - val_loss: 1.3102 - val_accuracy: 0.3889
# Epoch 45/300
#
# Epoch 00045: val_loss improved from 1.31023 to 1.30413, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9272 - accuracy: 0.5833 - val_loss: 1.3041 - val_accuracy: 0.3611
# Epoch 46/300
#
# Epoch 00046: val_loss improved from 1.30413 to 1.29400, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9165 - accuracy: 0.5764 - val_loss: 1.2940 - val_accuracy: 0.3750
# Epoch 47/300
#
# Epoch 00047: val_loss improved from 1.29400 to 1.28371, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9160 - accuracy: 0.6111 - val_loss: 1.2837 - val_accuracy: 0.3889
# Epoch 48/300
#
# Epoch 00048: val_loss improved from 1.28371 to 1.27666, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8879 - accuracy: 0.6597 - val_loss: 1.2767 - val_accuracy: 0.3750
# Epoch 49/300
#
# Epoch 00049: val_loss improved from 1.27666 to 1.26835, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9066 - accuracy: 0.5972 - val_loss: 1.2683 - val_accuracy: 0.4306
# Epoch 50/300
#
# Epoch 00050: val_loss improved from 1.26835 to 1.26045, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9020 - accuracy: 0.6042 - val_loss: 1.2604 - val_accuracy: 0.3750
# Epoch 51/300
#
# Epoch 00051: val_loss improved from 1.26045 to 1.25269, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8998 - accuracy: 0.6250 - val_loss: 1.2527 - val_accuracy: 0.4028
# Epoch 52/300
#
# Epoch 00052: val_loss improved from 1.25269 to 1.24485, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.9103 - accuracy: 0.5833 - val_loss: 1.2448 - val_accuracy: 0.3889
# Epoch 53/300
#
# Epoch 00053: val_loss improved from 1.24485 to 1.23978, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8810 - accuracy: 0.6319 - val_loss: 1.2398 - val_accuracy: 0.4028
# Epoch 54/300
#
# Epoch 00054: val_loss improved from 1.23978 to 1.23050, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8921 - accuracy: 0.6389 - val_loss: 1.2305 - val_accuracy: 0.3889
# Epoch 55/300
#
# Epoch 00055: val_loss improved from 1.23050 to 1.22257, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8906 - accuracy: 0.6389 - val_loss: 1.2226 - val_accuracy: 0.4167
# Epoch 56/300
#
# Epoch 00056: val_loss improved from 1.22257 to 1.21571, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8521 - accuracy: 0.7014 - val_loss: 1.2157 - val_accuracy: 0.4028
# Epoch 57/300
#
# Epoch 00057: val_loss improved from 1.21571 to 1.20761, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8731 - accuracy: 0.7083 - val_loss: 1.2076 - val_accuracy: 0.4028
# Epoch 58/300
#
# Epoch 00058: val_loss improved from 1.20761 to 1.19923, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8623 - accuracy: 0.6458 - val_loss: 1.1992 - val_accuracy: 0.4444
# Epoch 59/300
#
# Epoch 00059: val_loss improved from 1.19923 to 1.19236, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8601 - accuracy: 0.5972 - val_loss: 1.1924 - val_accuracy: 0.4583
# Epoch 60/300
#
# Epoch 00060: val_loss improved from 1.19236 to 1.17549, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8603 - accuracy: 0.7292 - val_loss: 1.1755 - val_accuracy: 0.4444
# Epoch 61/300
#
# Epoch 00061: val_loss improved from 1.17549 to 1.16383, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8637 - accuracy: 0.6875 - val_loss: 1.1638 - val_accuracy: 0.4861
# Epoch 62/300
#
# Epoch 00062: val_loss improved from 1.16383 to 1.15902, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8403 - accuracy: 0.7222 - val_loss: 1.1590 - val_accuracy: 0.4306
# Epoch 63/300
#
# Epoch 00063: val_loss improved from 1.15902 to 1.15350, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8215 - accuracy: 0.7083 - val_loss: 1.1535 - val_accuracy: 0.4722
# Epoch 64/300
#
# Epoch 00064: val_loss improved from 1.15350 to 1.13384, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8766 - accuracy: 0.6389 - val_loss: 1.1338 - val_accuracy: 0.4722
# Epoch 65/300
#
# Epoch 00065: val_loss improved from 1.13384 to 1.12072, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8374 - accuracy: 0.6597 - val_loss: 1.1207 - val_accuracy: 0.5278
# Epoch 66/300
#
# Epoch 00066: val_loss improved from 1.12072 to 1.11662, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8125 - accuracy: 0.7083 - val_loss: 1.1166 - val_accuracy: 0.5139
# Epoch 67/300
#
# Epoch 00067: val_loss improved from 1.11662 to 1.10884, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8216 - accuracy: 0.7014 - val_loss: 1.1088 - val_accuracy: 0.5556
# Epoch 68/300
#
# Epoch 00068: val_loss improved from 1.10884 to 1.10075, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8245 - accuracy: 0.7153 - val_loss: 1.1007 - val_accuracy: 0.5556
# Epoch 69/300
#
# Epoch 00069: val_loss improved from 1.10075 to 1.08552, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8112 - accuracy: 0.7083 - val_loss: 1.0855 - val_accuracy: 0.5556
# Epoch 70/300
#
# Epoch 00070: val_loss improved from 1.08552 to 1.07972, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8634 - accuracy: 0.6597 - val_loss: 1.0797 - val_accuracy: 0.5556
# Epoch 71/300
#
# Epoch 00071: val_loss improved from 1.07972 to 1.04946, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8162 - accuracy: 0.7153 - val_loss: 1.0495 - val_accuracy: 0.6389
# Epoch 72/300
#
# Epoch 00072: val_loss improved from 1.04946 to 1.04388, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8207 - accuracy: 0.7500 - val_loss: 1.0439 - val_accuracy: 0.6111
# Epoch 73/300
#
# Epoch 00073: val_loss improved from 1.04388 to 1.04290, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8279 - accuracy: 0.6389 - val_loss: 1.0429 - val_accuracy: 0.6389
# Epoch 74/300
#
# Epoch 00074: val_loss did not improve from 1.04290
# 9/9 - 0s - loss: 0.7903 - accuracy: 0.7708 - val_loss: 1.0470 - val_accuracy: 0.6111
# Epoch 75/300
#
# Epoch 00075: val_loss improved from 1.04290 to 1.03795, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7949 - accuracy: 0.7639 - val_loss: 1.0379 - val_accuracy: 0.6111
# Epoch 76/300
#
# Epoch 00076: val_loss improved from 1.03795 to 1.02324, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.8070 - accuracy: 0.7708 - val_loss: 1.0232 - val_accuracy: 0.6389
# Epoch 77/300
#
# Epoch 00077: val_loss improved from 1.02324 to 1.02000, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7788 - accuracy: 0.7569 - val_loss: 1.0200 - val_accuracy: 0.6250
# Epoch 78/300
#
# Epoch 00078: val_loss improved from 1.02000 to 1.00790, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7879 - accuracy: 0.7569 - val_loss: 1.0079 - val_accuracy: 0.6111
# Epoch 79/300
#
# Epoch 00079: val_loss did not improve from 1.00790
# 9/9 - 0s - loss: 0.7696 - accuracy: 0.7083 - val_loss: 1.0121 - val_accuracy: 0.5417
# Epoch 80/300
#
# Epoch 00080: val_loss improved from 1.00790 to 0.99165, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7724 - accuracy: 0.7153 - val_loss: 0.9916 - val_accuracy: 0.6389
# Epoch 81/300
#
# Epoch 00081: val_loss did not improve from 0.99165
# 9/9 - 0s - loss: 0.7708 - accuracy: 0.7361 - val_loss: 1.0015 - val_accuracy: 0.6250
# Epoch 82/300
#
# Epoch 00082: val_loss improved from 0.99165 to 0.99143, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7687 - accuracy: 0.7569 - val_loss: 0.9914 - val_accuracy: 0.6250
# Epoch 83/300
#
# Epoch 00083: val_loss improved from 0.99143 to 0.98537, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7813 - accuracy: 0.7431 - val_loss: 0.9854 - val_accuracy: 0.6250
# Epoch 84/300
#
# Epoch 00084: val_loss did not improve from 0.98537
# 9/9 - 0s - loss: 0.7884 - accuracy: 0.7083 - val_loss: 0.9975 - val_accuracy: 0.5972
# Epoch 85/300
#
# Epoch 00085: val_loss did not improve from 0.98537
# 9/9 - 0s - loss: 0.7605 - accuracy: 0.7847 - val_loss: 0.9936 - val_accuracy: 0.5694
# Epoch 86/300
#
# Epoch 00086: val_loss improved from 0.98537 to 0.97920, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7249 - accuracy: 0.8125 - val_loss: 0.9792 - val_accuracy: 0.6250
# Epoch 87/300
#
# Epoch 00087: val_loss improved from 0.97920 to 0.97687, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7836 - accuracy: 0.6944 - val_loss: 0.9769 - val_accuracy: 0.6389
# Epoch 88/300
#
# Epoch 00088: val_loss improved from 0.97687 to 0.97534, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7783 - accuracy: 0.7431 - val_loss: 0.9753 - val_accuracy: 0.5833
# Epoch 89/300
#
# Epoch 00089: val_loss improved from 0.97534 to 0.96066, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7605 - accuracy: 0.7986 - val_loss: 0.9607 - val_accuracy: 0.6111
# Epoch 90/300
#
# Epoch 00090: val_loss did not improve from 0.96066
# 9/9 - 0s - loss: 0.7515 - accuracy: 0.7778 - val_loss: 0.9885 - val_accuracy: 0.5417
# Epoch 91/300
#
# Epoch 00091: val_loss improved from 0.96066 to 0.94517, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7875 - accuracy: 0.6736 - val_loss: 0.9452 - val_accuracy: 0.6667
# Epoch 92/300
#
# Epoch 00092: val_loss did not improve from 0.94517
# 9/9 - 0s - loss: 0.7405 - accuracy: 0.7222 - val_loss: 0.9507 - val_accuracy: 0.6111
# Epoch 93/300
#
# Epoch 00093: val_loss did not improve from 0.94517
# 9/9 - 0s - loss: 0.7212 - accuracy: 0.7986 - val_loss: 0.9491 - val_accuracy: 0.5972
# Epoch 94/300
#
# Epoch 00094: val_loss did not improve from 0.94517
# 9/9 - 0s - loss: 0.7177 - accuracy: 0.7500 - val_loss: 0.9465 - val_accuracy: 0.5833
# Epoch 95/300
#
# Epoch 00095: val_loss did not improve from 0.94517
# 9/9 - 0s - loss: 0.7822 - accuracy: 0.7500 - val_loss: 0.9468 - val_accuracy: 0.5833
# Epoch 96/300
#
# Epoch 00096: val_loss improved from 0.94517 to 0.92148, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7517 - accuracy: 0.7222 - val_loss: 0.9215 - val_accuracy: 0.6250
# Epoch 97/300
#
# Epoch 00097: val_loss did not improve from 0.92148
# 9/9 - 0s - loss: 0.7072 - accuracy: 0.7569 - val_loss: 0.9304 - val_accuracy: 0.6111
# Epoch 98/300
#
# Epoch 00098: val_loss improved from 0.92148 to 0.92078, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.7198 - accuracy: 0.7986 - val_loss: 0.9208 - val_accuracy: 0.5833
# Epoch 99/300
#
# Epoch 00099: val_loss did not improve from 0.92078
# 9/9 - 0s - loss: 0.6759 - accuracy: 0.7847 - val_loss: 0.9210 - val_accuracy: 0.6389
# Epoch 100/300
#
# Epoch 00100: val_loss did not improve from 0.92078
# 9/9 - 0s - loss: 0.7132 - accuracy: 0.7986 - val_loss: 0.9300 - val_accuracy: 0.6111
# Epoch 101/300
#
# Epoch 00101: val_loss did not improve from 0.92078
# 9/9 - 0s - loss: 0.6791 - accuracy: 0.8264 - val_loss: 0.9326 - val_accuracy: 0.5417
# Epoch 102/300
#
# Epoch 00102: val_loss did not improve from 0.92078
# 9/9 - 0s - loss: 0.7139 - accuracy: 0.7847 - val_loss: 0.9364 - val_accuracy: 0.5694
# Epoch 103/300
#
# Epoch 00103: val_loss improved from 0.92078 to 0.91034, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.6869 - accuracy: 0.7986 - val_loss: 0.9103 - val_accuracy: 0.6528
# Epoch 104/300
#
# Epoch 00104: val_loss did not improve from 0.91034
# 9/9 - 0s - loss: 0.6766 - accuracy: 0.7778 - val_loss: 0.9177 - val_accuracy: 0.5972
# Epoch 105/300
#
# Epoch 00105: val_loss did not improve from 0.91034
# 9/9 - 0s - loss: 0.7062 - accuracy: 0.7431 - val_loss: 0.9119 - val_accuracy: 0.6111
# Epoch 106/300
#
# Epoch 00106: val_loss did not improve from 0.91034
# 9/9 - 0s - loss: 0.6890 - accuracy: 0.8056 - val_loss: 0.9256 - val_accuracy: 0.5833
# Epoch 107/300
#
# Epoch 00107: val_loss did not improve from 0.91034
# 9/9 - 0s - loss: 0.6605 - accuracy: 0.7986 - val_loss: 0.9289 - val_accuracy: 0.5556
# Epoch 108/300
#
# Epoch 00108: val_loss did not improve from 0.91034
# 9/9 - 0s - loss: 0.6848 - accuracy: 0.8056 - val_loss: 0.9249 - val_accuracy: 0.6250
# Epoch 109/300
#
# Epoch 00109: val_loss did not improve from 0.91034
# 9/9 - 0s - loss: 0.6854 - accuracy: 0.7569 - val_loss: 0.9391 - val_accuracy: 0.5972
# Epoch 110/300
#
# Epoch 00110: val_loss did not improve from 0.91034
# 9/9 - 0s - loss: 0.7449 - accuracy: 0.7292 - val_loss: 0.9114 - val_accuracy: 0.5694
# Epoch 111/300
#
# Epoch 00111: val_loss improved from 0.91034 to 0.89676, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.6872 - accuracy: 0.7986 - val_loss: 0.8968 - val_accuracy: 0.6111
# Epoch 112/300
#
# Epoch 00112: val_loss did not improve from 0.89676
# 9/9 - 0s - loss: 0.6809 - accuracy: 0.7917 - val_loss: 0.9218 - val_accuracy: 0.5972
# Epoch 113/300
#
# Epoch 00113: val_loss did not improve from 0.89676
# 9/9 - 0s - loss: 0.6754 - accuracy: 0.7917 - val_loss: 0.9477 - val_accuracy: 0.5417
# Epoch 114/300
#
# Epoch 00114: val_loss did not improve from 0.89676
# 9/9 - 0s - loss: 0.6830 - accuracy: 0.7708 - val_loss: 0.9250 - val_accuracy: 0.6250
# Epoch 115/300
#
# Epoch 00115: val_loss did not improve from 0.89676
# 9/9 - 0s - loss: 0.6603 - accuracy: 0.7986 - val_loss: 0.9356 - val_accuracy: 0.5833
# Epoch 116/300
#
# Epoch 00116: val_loss did not improve from 0.89676
# 9/9 - 0s - loss: 0.6513 - accuracy: 0.7986 - val_loss: 0.9234 - val_accuracy: 0.5833
# Epoch 117/300
#
# Epoch 00117: val_loss did not improve from 0.89676
# 9/9 - 0s - loss: 0.6378 - accuracy: 0.8333 - val_loss: 0.9123 - val_accuracy: 0.5694
# Epoch 118/300
#
# Epoch 00118: val_loss improved from 0.89676 to 0.88313, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.6594 - accuracy: 0.8403 - val_loss: 0.8831 - val_accuracy: 0.6389
# Epoch 119/300
#
# Epoch 00119: val_loss did not improve from 0.88313
# 9/9 - 0s - loss: 0.6888 - accuracy: 0.7917 - val_loss: 0.8974 - val_accuracy: 0.5972
# Epoch 120/300
#
# Epoch 00120: val_loss did not improve from 0.88313
# 9/9 - 0s - loss: 0.6445 - accuracy: 0.8264 - val_loss: 0.9271 - val_accuracy: 0.5833
# Epoch 121/300
#
# Epoch 00121: val_loss did not improve from 0.88313
# 9/9 - 0s - loss: 0.6283 - accuracy: 0.8472 - val_loss: 0.8853 - val_accuracy: 0.6528
# Epoch 122/300
#
# Epoch 00122: val_loss did not improve from 0.88313
# 9/9 - 0s - loss: 0.6542 - accuracy: 0.8125 - val_loss: 0.9282 - val_accuracy: 0.5972
# Epoch 123/300
#
# Epoch 00123: val_loss did not improve from 0.88313
# 9/9 - 0s - loss: 0.6546 - accuracy: 0.8056 - val_loss: 0.9181 - val_accuracy: 0.5833
# Epoch 124/300
#
# Epoch 00124: val_loss improved from 0.88313 to 0.88102, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.6629 - accuracy: 0.8472 - val_loss: 0.8810 - val_accuracy: 0.6250
# Epoch 125/300
#
# Epoch 00125: val_loss did not improve from 0.88102
# 9/9 - 0s - loss: 0.6433 - accuracy: 0.7986 - val_loss: 0.8940 - val_accuracy: 0.5972
# Epoch 126/300
#
# Epoch 00126: val_loss did not improve from 0.88102
# 9/9 - 0s - loss: 0.6442 - accuracy: 0.7986 - val_loss: 0.8915 - val_accuracy: 0.6111
# Epoch 127/300
#
# Epoch 00127: val_loss did not improve from 0.88102
# 9/9 - 0s - loss: 0.6313 - accuracy: 0.8472 - val_loss: 0.8845 - val_accuracy: 0.5833
# Epoch 128/300
#
# Epoch 00128: val_loss improved from 0.88102 to 0.87738, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.6271 - accuracy: 0.8194 - val_loss: 0.8774 - val_accuracy: 0.6111
# Epoch 129/300
#
# Epoch 00129: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6322 - accuracy: 0.8194 - val_loss: 0.8886 - val_accuracy: 0.5972
# Epoch 130/300
#
# Epoch 00130: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6015 - accuracy: 0.8611 - val_loss: 0.8996 - val_accuracy: 0.5833
# Epoch 131/300
#
# Epoch 00131: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6034 - accuracy: 0.8750 - val_loss: 0.8876 - val_accuracy: 0.5833
# Epoch 132/300
#
# Epoch 00132: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6397 - accuracy: 0.8264 - val_loss: 0.9312 - val_accuracy: 0.5972
# Epoch 133/300
#
# Epoch 00133: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6313 - accuracy: 0.8264 - val_loss: 0.9113 - val_accuracy: 0.5972
# Epoch 134/300
#
# Epoch 00134: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6469 - accuracy: 0.7847 - val_loss: 0.9246 - val_accuracy: 0.5556
# Epoch 135/300
#
# Epoch 00135: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6500 - accuracy: 0.7778 - val_loss: 0.8808 - val_accuracy: 0.5694
# Epoch 136/300
#
# Epoch 00136: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6155 - accuracy: 0.8403 - val_loss: 0.8828 - val_accuracy: 0.6250
# Epoch 137/300
#
# Epoch 00137: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6006 - accuracy: 0.8542 - val_loss: 0.8928 - val_accuracy: 0.5833
# Epoch 138/300
#
# Epoch 00138: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.5990 - accuracy: 0.8056 - val_loss: 0.8940 - val_accuracy: 0.5694
# Epoch 139/300
#
# Epoch 00139: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6253 - accuracy: 0.8472 - val_loss: 0.9001 - val_accuracy: 0.5694
# Epoch 140/300
#
# Epoch 00140: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6185 - accuracy: 0.8403 - val_loss: 0.9114 - val_accuracy: 0.5556
# Epoch 141/300
#
# Epoch 00141: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.5819 - accuracy: 0.8333 - val_loss: 0.8844 - val_accuracy: 0.5972
# Epoch 142/300
#
# Epoch 00142: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.6199 - accuracy: 0.8056 - val_loss: 0.8919 - val_accuracy: 0.5833
# Epoch 143/300
#
# Epoch 00143: val_loss did not improve from 0.87738
# 9/9 - 0s - loss: 0.5768 - accuracy: 0.8542 - val_loss: 0.9132 - val_accuracy: 0.5139
# Epoch 144/300
#
# Epoch 00144: val_loss improved from 0.87738 to 0.87616, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.5992 - accuracy: 0.8333 - val_loss: 0.8762 - val_accuracy: 0.5972
# Epoch 145/300
#
# Epoch 00145: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5246 - accuracy: 0.8472 - val_loss: 0.8994 - val_accuracy: 0.5556
# Epoch 146/300
#
# Epoch 00146: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5820 - accuracy: 0.8264 - val_loss: 0.9088 - val_accuracy: 0.5694
# Epoch 147/300
#
# Epoch 00147: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5513 - accuracy: 0.8819 - val_loss: 0.9079 - val_accuracy: 0.5833
# Epoch 148/300
#
# Epoch 00148: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5952 - accuracy: 0.8611 - val_loss: 0.9232 - val_accuracy: 0.5417
# Epoch 149/300
#
# Epoch 00149: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5533 - accuracy: 0.8611 - val_loss: 0.8879 - val_accuracy: 0.6111
# Epoch 150/300
#
# Epoch 00150: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5543 - accuracy: 0.8681 - val_loss: 0.8870 - val_accuracy: 0.5972
# Epoch 151/300
#
# Epoch 00151: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5575 - accuracy: 0.8889 - val_loss: 0.8866 - val_accuracy: 0.5694
# Epoch 152/300
#
# Epoch 00152: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5330 - accuracy: 0.8681 - val_loss: 0.8794 - val_accuracy: 0.6389
# Epoch 153/300
#
# Epoch 00153: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5330 - accuracy: 0.8750 - val_loss: 0.9145 - val_accuracy: 0.5556
# Epoch 154/300
#
# Epoch 00154: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5687 - accuracy: 0.8819 - val_loss: 0.8819 - val_accuracy: 0.5972
# Epoch 155/300
#
# Epoch 00155: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5370 - accuracy: 0.8333 - val_loss: 0.8870 - val_accuracy: 0.5694
# Epoch 156/300
#
# Epoch 00156: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5853 - accuracy: 0.8403 - val_loss: 0.9176 - val_accuracy: 0.5417
# Epoch 157/300
#
# Epoch 00157: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.6185 - accuracy: 0.7986 - val_loss: 0.8893 - val_accuracy: 0.6111
# Epoch 158/300
#
# Epoch 00158: val_loss did not improve from 0.87616
# 9/9 - 0s - loss: 0.5482 - accuracy: 0.8750 - val_loss: 0.9001 - val_accuracy: 0.5417
# Epoch 159/300
#
# Epoch 00159: val_loss improved from 0.87616 to 0.86862, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.5881 - accuracy: 0.8403 - val_loss: 0.8686 - val_accuracy: 0.5833
# Epoch 160/300
#
# Epoch 00160: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5292 - accuracy: 0.8611 - val_loss: 0.9057 - val_accuracy: 0.5694
# Epoch 161/300
#
# Epoch 00161: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5500 - accuracy: 0.8403 - val_loss: 0.8857 - val_accuracy: 0.5694
# Epoch 162/300
#
# Epoch 00162: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5320 - accuracy: 0.8681 - val_loss: 0.8826 - val_accuracy: 0.6389
# Epoch 163/300
#
# Epoch 00163: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5599 - accuracy: 0.8333 - val_loss: 0.9018 - val_accuracy: 0.5417
# Epoch 164/300
#
# Epoch 00164: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5326 - accuracy: 0.8889 - val_loss: 0.8730 - val_accuracy: 0.5972
# Epoch 165/300
#
# Epoch 00165: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5534 - accuracy: 0.8819 - val_loss: 0.9097 - val_accuracy: 0.5556
# Epoch 166/300
#
# Epoch 00166: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5892 - accuracy: 0.8472 - val_loss: 0.8866 - val_accuracy: 0.5556
# Epoch 167/300
#
# Epoch 00167: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5318 - accuracy: 0.8750 - val_loss: 0.9342 - val_accuracy: 0.5556
# Epoch 168/300
#
# Epoch 00168: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5077 - accuracy: 0.8750 - val_loss: 0.9229 - val_accuracy: 0.5556
# Epoch 169/300
#
# Epoch 00169: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5379 - accuracy: 0.8542 - val_loss: 0.9122 - val_accuracy: 0.4861
# Epoch 170/300
#
# Epoch 00170: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5078 - accuracy: 0.8611 - val_loss: 0.9022 - val_accuracy: 0.5694
# Epoch 171/300
#
# Epoch 00171: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.4767 - accuracy: 0.9514 - val_loss: 0.8745 - val_accuracy: 0.5556
# Epoch 172/300
#
# Epoch 00172: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.4941 - accuracy: 0.8958 - val_loss: 0.9011 - val_accuracy: 0.5417
# Epoch 173/300
#
# Epoch 00173: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5006 - accuracy: 0.8819 - val_loss: 0.8896 - val_accuracy: 0.5556
# Epoch 174/300
#
# Epoch 00174: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5264 - accuracy: 0.8958 - val_loss: 0.8926 - val_accuracy: 0.5694
# Epoch 175/300
#
# Epoch 00175: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5079 - accuracy: 0.8681 - val_loss: 0.8742 - val_accuracy: 0.5694
# Epoch 176/300
#
# Epoch 00176: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5241 - accuracy: 0.8542 - val_loss: 0.8935 - val_accuracy: 0.5694
# Epoch 177/300
#
# Epoch 00177: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5491 - accuracy: 0.8542 - val_loss: 0.9054 - val_accuracy: 0.5556
# Epoch 178/300
#
# Epoch 00178: val_loss did not improve from 0.86862
# 9/9 - 0s - loss: 0.5064 - accuracy: 0.8611 - val_loss: 0.8874 - val_accuracy: 0.5833
# Epoch 179/300
#
# Epoch 00179: val_loss improved from 0.86862 to 0.85925, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.5219 - accuracy: 0.8681 - val_loss: 0.8593 - val_accuracy: 0.5694
# Epoch 180/300
#
# Epoch 00180: val_loss improved from 0.85925 to 0.85373, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.5236 - accuracy: 0.8611 - val_loss: 0.8537 - val_accuracy: 0.5833
# Epoch 181/300
#
# Epoch 00181: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.4938 - accuracy: 0.8958 - val_loss: 0.8610 - val_accuracy: 0.5972
# Epoch 182/300
#
# Epoch 00182: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.5219 - accuracy: 0.8681 - val_loss: 0.8751 - val_accuracy: 0.5417
# Epoch 183/300
#
# Epoch 00183: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.5179 - accuracy: 0.8889 - val_loss: 0.8956 - val_accuracy: 0.5417
# Epoch 184/300
#
# Epoch 00184: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.5171 - accuracy: 0.8819 - val_loss: 0.9270 - val_accuracy: 0.4861
# Epoch 185/300
#
# Epoch 00185: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.5107 - accuracy: 0.8750 - val_loss: 0.8825 - val_accuracy: 0.5694
# Epoch 186/300
#
# Epoch 00186: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.5395 - accuracy: 0.8681 - val_loss: 0.9200 - val_accuracy: 0.5278
# Epoch 187/300
#
# Epoch 00187: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.5222 - accuracy: 0.8611 - val_loss: 0.8677 - val_accuracy: 0.5417
# Epoch 188/300
#
# Epoch 00188: val_loss did not improve from 0.85373
# 9/9 - 0s - loss: 0.4941 - accuracy: 0.9097 - val_loss: 0.9051 - val_accuracy: 0.5556
# Epoch 189/300
#
# Epoch 00189: val_loss improved from 0.85373 to 0.84444, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.4863 - accuracy: 0.8819 - val_loss: 0.8444 - val_accuracy: 0.5833
# Epoch 190/300
#
# Epoch 00190: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.5055 - accuracy: 0.8889 - val_loss: 0.8675 - val_accuracy: 0.5833
# Epoch 191/300
#
# Epoch 00191: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.5104 - accuracy: 0.8750 - val_loss: 0.8838 - val_accuracy: 0.5556
# Epoch 192/300
#
# Epoch 00192: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.5010 - accuracy: 0.8542 - val_loss: 0.8622 - val_accuracy: 0.5417
# Epoch 193/300
#
# Epoch 00193: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4978 - accuracy: 0.8611 - val_loss: 0.9010 - val_accuracy: 0.5278
# Epoch 194/300
#
# Epoch 00194: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4646 - accuracy: 0.8750 - val_loss: 0.8878 - val_accuracy: 0.5556
# Epoch 195/300
#
# Epoch 00195: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4845 - accuracy: 0.8889 - val_loss: 0.9340 - val_accuracy: 0.4861
# Epoch 196/300
#
# Epoch 00196: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.5454 - accuracy: 0.8819 - val_loss: 0.8641 - val_accuracy: 0.5694
# Epoch 197/300
#
# Epoch 00197: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4941 - accuracy: 0.8472 - val_loss: 0.8901 - val_accuracy: 0.5694
# Epoch 198/300
#
# Epoch 00198: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.5385 - accuracy: 0.8403 - val_loss: 0.8826 - val_accuracy: 0.5556
# Epoch 199/300
#
# Epoch 00199: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.5026 - accuracy: 0.8681 - val_loss: 0.8567 - val_accuracy: 0.5417
# Epoch 200/300
#
# Epoch 00200: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4651 - accuracy: 0.8889 - val_loss: 0.8983 - val_accuracy: 0.5278
# Epoch 201/300
#
# Epoch 00201: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4904 - accuracy: 0.8819 - val_loss: 0.8750 - val_accuracy: 0.5278
# Epoch 202/300
#
# Epoch 00202: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4404 - accuracy: 0.9097 - val_loss: 0.8487 - val_accuracy: 0.5833
# Epoch 203/300
#
# Epoch 00203: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4667 - accuracy: 0.8889 - val_loss: 0.8697 - val_accuracy: 0.5833
# Epoch 204/300
#
# Epoch 00204: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4707 - accuracy: 0.8958 - val_loss: 0.8887 - val_accuracy: 0.5417
# Epoch 205/300
#
# Epoch 00205: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4783 - accuracy: 0.8819 - val_loss: 0.8690 - val_accuracy: 0.5417
# Epoch 206/300
#
# Epoch 00206: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4745 - accuracy: 0.9028 - val_loss: 0.9065 - val_accuracy: 0.5417
# Epoch 207/300
#
# Epoch 00207: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4893 - accuracy: 0.8333 - val_loss: 0.8747 - val_accuracy: 0.5556
# Epoch 208/300
#
# Epoch 00208: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4778 - accuracy: 0.8611 - val_loss: 0.8853 - val_accuracy: 0.5833
# Epoch 209/300
#
# Epoch 00209: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4751 - accuracy: 0.8542 - val_loss: 0.9052 - val_accuracy: 0.5694
# Epoch 210/300
#
# Epoch 00210: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4821 - accuracy: 0.9097 - val_loss: 0.8699 - val_accuracy: 0.5833
# Epoch 211/300
#
# Epoch 00211: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4475 - accuracy: 0.8889 - val_loss: 0.8494 - val_accuracy: 0.5417
# Epoch 212/300
#
# Epoch 00212: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4760 - accuracy: 0.8819 - val_loss: 0.8566 - val_accuracy: 0.5556
# Epoch 213/300
#
# Epoch 00213: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4453 - accuracy: 0.9028 - val_loss: 0.8704 - val_accuracy: 0.5417
# Epoch 214/300
#
# Epoch 00214: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4433 - accuracy: 0.9236 - val_loss: 0.9138 - val_accuracy: 0.5417
# Epoch 215/300
#
# Epoch 00215: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4067 - accuracy: 0.8958 - val_loss: 0.8827 - val_accuracy: 0.5694
# Epoch 216/300
#
# Epoch 00216: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4644 - accuracy: 0.8889 - val_loss: 0.9153 - val_accuracy: 0.5694
# Epoch 217/300
#
# Epoch 00217: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4807 - accuracy: 0.8333 - val_loss: 0.8933 - val_accuracy: 0.5972
# Epoch 218/300
#
# Epoch 00218: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4248 - accuracy: 0.9097 - val_loss: 0.9021 - val_accuracy: 0.5694
# Epoch 219/300
#
# Epoch 00219: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4687 - accuracy: 0.8958 - val_loss: 0.8701 - val_accuracy: 0.5833
# Epoch 220/300
#
# Epoch 00220: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4433 - accuracy: 0.9236 - val_loss: 0.8807 - val_accuracy: 0.5972
# Epoch 221/300
#
# Epoch 00221: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4484 - accuracy: 0.9028 - val_loss: 0.8919 - val_accuracy: 0.5556
# Epoch 222/300
#
# Epoch 00222: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4477 - accuracy: 0.9097 - val_loss: 0.8895 - val_accuracy: 0.5694
# Epoch 223/300
#
# Epoch 00223: val_loss did not improve from 0.84444
# 9/9 - 0s - loss: 0.4558 - accuracy: 0.8889 - val_loss: 0.9014 - val_accuracy: 0.5556
# Epoch 224/300
#
# Epoch 00224: val_loss improved from 0.84444 to 0.83485, saving model to checkpoint.h5
# 9/9 - 0s - loss: 0.4510 - accuracy: 0.8750 - val_loss: 0.8348 - val_accuracy: 0.6250
# Epoch 225/300
#
# Epoch 00225: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4362 - accuracy: 0.9236 - val_loss: 0.8617 - val_accuracy: 0.5833
# Epoch 226/300
#
# Epoch 00226: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4298 - accuracy: 0.9167 - val_loss: 0.8812 - val_accuracy: 0.5417
# Epoch 227/300
#
# Epoch 00227: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4015 - accuracy: 0.9444 - val_loss: 0.9121 - val_accuracy: 0.5694
# Epoch 228/300
#
# Epoch 00228: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4382 - accuracy: 0.9028 - val_loss: 0.9458 - val_accuracy: 0.5139
# Epoch 229/300
#
# Epoch 00229: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4520 - accuracy: 0.8889 - val_loss: 0.9151 - val_accuracy: 0.5694
# Epoch 230/300
#
# Epoch 00230: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4233 - accuracy: 0.9375 - val_loss: 0.9391 - val_accuracy: 0.5278
# Epoch 231/300
#
# Epoch 00231: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4678 - accuracy: 0.8611 - val_loss: 0.9411 - val_accuracy: 0.5000
# Epoch 232/300
#
# Epoch 00232: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4865 - accuracy: 0.8264 - val_loss: 0.9227 - val_accuracy: 0.5694
# Epoch 233/300
#
# Epoch 00233: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3932 - accuracy: 0.8819 - val_loss: 0.8947 - val_accuracy: 0.5833
# Epoch 234/300
#
# Epoch 00234: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4401 - accuracy: 0.8958 - val_loss: 0.8707 - val_accuracy: 0.5556
# Epoch 235/300
#
# Epoch 00235: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4256 - accuracy: 0.8681 - val_loss: 0.9016 - val_accuracy: 0.5833
# Epoch 236/300
#
# Epoch 00236: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4341 - accuracy: 0.9167 - val_loss: 0.8993 - val_accuracy: 0.5278
# Epoch 237/300
#
# Epoch 00237: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4561 - accuracy: 0.8611 - val_loss: 0.9067 - val_accuracy: 0.5556
# Epoch 238/300
#
# Epoch 00238: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4482 - accuracy: 0.8542 - val_loss: 0.9064 - val_accuracy: 0.5000
# Epoch 239/300
#
# Epoch 00239: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4287 - accuracy: 0.9028 - val_loss: 0.8816 - val_accuracy: 0.5972
# Epoch 240/300
#
# Epoch 00240: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3868 - accuracy: 0.9097 - val_loss: 0.8819 - val_accuracy: 0.5278
# Epoch 241/300
#
# Epoch 00241: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4306 - accuracy: 0.9306 - val_loss: 0.8923 - val_accuracy: 0.5694
# Epoch 242/300
#
# Epoch 00242: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3933 - accuracy: 0.8889 - val_loss: 0.8922 - val_accuracy: 0.5139
# Epoch 243/300
#
# Epoch 00243: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3887 - accuracy: 0.9444 - val_loss: 0.9157 - val_accuracy: 0.5694
# Epoch 244/300
#
# Epoch 00244: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4474 - accuracy: 0.9028 - val_loss: 0.9427 - val_accuracy: 0.5694
# Epoch 245/300
#
# Epoch 00245: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4283 - accuracy: 0.8958 - val_loss: 0.9046 - val_accuracy: 0.5417
# Epoch 246/300
#
# Epoch 00246: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3993 - accuracy: 0.9514 - val_loss: 0.8925 - val_accuracy: 0.5417
# Epoch 247/300
#
# Epoch 00247: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4100 - accuracy: 0.9028 - val_loss: 0.8808 - val_accuracy: 0.5417
# Epoch 248/300
#
# Epoch 00248: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4039 - accuracy: 0.9306 - val_loss: 0.8757 - val_accuracy: 0.5278
# Epoch 249/300
#
# Epoch 00249: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3831 - accuracy: 0.9444 - val_loss: 0.8374 - val_accuracy: 0.5833
# Epoch 250/300
#
# Epoch 00250: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4028 - accuracy: 0.9097 - val_loss: 0.8655 - val_accuracy: 0.6111
# Epoch 251/300
#
# Epoch 00251: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3673 - accuracy: 0.9444 - val_loss: 0.8822 - val_accuracy: 0.5556
# Epoch 252/300
#
# Epoch 00252: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3783 - accuracy: 0.9306 - val_loss: 0.8969 - val_accuracy: 0.5833
# Epoch 253/300
# Epoch 00253: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4160 - accuracy: 0.9167 - val_loss: 0.9391 - val_accuracy: 0.5556
# Epoch 254/300
#
# Epoch 00254: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4185 - accuracy: 0.9236 - val_loss: 0.8901 - val_accuracy: 0.5556
# Epoch 255/300
#
# Epoch 00255: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4246 - accuracy: 0.9028 - val_loss: 0.8767 - val_accuracy: 0.5833
# Epoch 256/300
#
# Epoch 00256: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4025 - accuracy: 0.9306 - val_loss: 0.8838 - val_accuracy: 0.5694
# Epoch 257/300
#
# Epoch 00257: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4079 - accuracy: 0.9167 - val_loss: 0.8782 - val_accuracy: 0.5972
# Epoch 258/300
#
# Epoch 00258: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4041 - accuracy: 0.9097 - val_loss: 0.9149 - val_accuracy: 0.5417
# Epoch 259/300
#
# Epoch 00259: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3900 - accuracy: 0.9236 - val_loss: 0.8601 - val_accuracy: 0.5833
# Epoch 260/300
#
# Epoch 00260: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4000 - accuracy: 0.9028 - val_loss: 0.8633 - val_accuracy: 0.5556
# Epoch 261/300
#
# Epoch 00261: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3637 - accuracy: 0.9306 - val_loss: 0.9153 - val_accuracy: 0.5556
# Epoch 262/300
#
# Epoch 00262: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3886 - accuracy: 0.8958 - val_loss: 0.9022 - val_accuracy: 0.5278
# Epoch 263/300
#
# Epoch 00263: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4363 - accuracy: 0.9028 - val_loss: 0.9014 - val_accuracy: 0.5833
# Epoch 264/300
#
# Epoch 00264: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4547 - accuracy: 0.8750 - val_loss: 0.9208 - val_accuracy: 0.5417
# Epoch 265/300
#
# Epoch 00265: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3843 - accuracy: 0.9375 - val_loss: 0.8770 - val_accuracy: 0.5417
# Epoch 266/300
#
# Epoch 00266: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3582 - accuracy: 0.9236 - val_loss: 0.8824 - val_accuracy: 0.5972
# Epoch 267/300
#
# Epoch 00267: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3670 - accuracy: 0.9306 - val_loss: 0.8684 - val_accuracy: 0.6111
# Epoch 268/300
#
# Epoch 00268: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3924 - accuracy: 0.9028 - val_loss: 0.8686 - val_accuracy: 0.6111
# Epoch 269/300
#
# Epoch 00269: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3997 - accuracy: 0.9167 - val_loss: 0.8991 - val_accuracy: 0.5833
# Epoch 270/300
#
# Epoch 00270: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3489 - accuracy: 0.9444 - val_loss: 0.8662 - val_accuracy: 0.6111
# Epoch 271/300
#
# Epoch 00271: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3452 - accuracy: 0.9375 - val_loss: 0.8851 - val_accuracy: 0.5833
# Epoch 272/300
#
# Epoch 00272: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4015 - accuracy: 0.9097 - val_loss: 0.8883 - val_accuracy: 0.5556
# Epoch 273/300
#
# Epoch 00273: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3900 - accuracy: 0.9306 - val_loss: 0.8548 - val_accuracy: 0.5833
# Epoch 274/300
#
# Epoch 00274: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3423 - accuracy: 0.9167 - val_loss: 0.8891 - val_accuracy: 0.5556
# Epoch 275/300
#
# Epoch 00275: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3752 - accuracy: 0.9167 - val_loss: 0.8895 - val_accuracy: 0.5972
# Epoch 276/300
#
# Epoch 00276: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3582 - accuracy: 0.9444 - val_loss: 0.8698 - val_accuracy: 0.5972
# Epoch 277/300
#
# Epoch 00277: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3506 - accuracy: 0.9375 - val_loss: 0.8815 - val_accuracy: 0.5278
# Epoch 278/300
#
# Epoch 00278: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.4323 - accuracy: 0.8611 - val_loss: 0.8779 - val_accuracy: 0.5556
# Epoch 279/300
#
# Epoch 00279: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3787 - accuracy: 0.8889 - val_loss: 0.8953 - val_accuracy: 0.5139
# Epoch 280/300
#
# Epoch 00280: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3894 - accuracy: 0.9236 - val_loss: 0.8654 - val_accuracy: 0.5972
# Epoch 281/300
#
# Epoch 00281: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3754 - accuracy: 0.9097 - val_loss: 0.8879 - val_accuracy: 0.5417
# Epoch 282/300
#
# Epoch 00282: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3224 - accuracy: 0.9722 - val_loss: 0.8876 - val_accuracy: 0.5972
# Epoch 283/300
#
# Epoch 00283: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3629 - accuracy: 0.9236 - val_loss: 0.8736 - val_accuracy: 0.5833
# Epoch 284/300
#
# Epoch 00284: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3066 - accuracy: 0.9514 - val_loss: 0.9021 - val_accuracy: 0.5972
# Epoch 285/300
#
# Epoch 00285: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3615 - accuracy: 0.9306 - val_loss: 0.9200 - val_accuracy: 0.6111
# Epoch 286/300
#
# Epoch 00286: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3660 - accuracy: 0.9306 - val_loss: 0.9229 - val_accuracy: 0.6111
# Epoch 287/300
#
# Epoch 00287: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3391 - accuracy: 0.9236 - val_loss: 0.8857 - val_accuracy: 0.5972
# Epoch 288/300
#
# Epoch 00288: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3635 - accuracy: 0.9097 - val_loss: 0.8779 - val_accuracy: 0.5833
# Epoch 289/300
#
# Epoch 00289: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3649 - accuracy: 0.9028 - val_loss: 0.8944 - val_accuracy: 0.6111
# Epoch 290/300
#
# Epoch 00290: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3346 - accuracy: 0.9375 - val_loss: 0.8963 - val_accuracy: 0.6250
# Epoch 291/300
#
# Epoch 00291: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3455 - accuracy: 0.9583 - val_loss: 0.8807 - val_accuracy: 0.5139
# Epoch 292/300
#
# Epoch 00292: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3516 - accuracy: 0.9375 - val_loss: 0.9262 - val_accuracy: 0.5417
# Epoch 293/300
#
# Epoch 00293: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3564 - accuracy: 0.9375 - val_loss: 0.8659 - val_accuracy: 0.6250
# Epoch 294/300
#
# Epoch 00294: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3468 - accuracy: 0.9306 - val_loss: 0.9391 - val_accuracy: 0.5556
# Epoch 295/300
#
# Epoch 00295: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3450 - accuracy: 0.9306 - val_loss: 0.8655 - val_accuracy: 0.5694
# Epoch 296/300
#
# Epoch 00296: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3889 - accuracy: 0.9028 - val_loss: 0.8776 - val_accuracy: 0.5972
# Epoch 297/300
#
# Epoch 00297: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3555 - accuracy: 0.9236 - val_loss: 0.9505 - val_accuracy: 0.5417
# Epoch 298/300
#
# Epoch 00298: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3156 - accuracy: 0.9167 - val_loss: 0.8755 - val_accuracy: 0.5833
# Epoch 299/300
#
# Epoch 00299: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.2943 - accuracy: 0.9514 - val_loss: 0.9108 - val_accuracy: 0.5694
# Epoch 300/300
#
# Epoch 00300: val_loss did not improve from 0.83485
# 9/9 - 0s - loss: 0.3452 - accuracy: 0.9167 - val_loss: 0.8869 - val_accuracy: 0.5972

# %%
###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

WEIGHTS_PATH = "EEGNet-8-2-weights.h5"
model.load_weights(WEIGHTS_PATH)

# %%
###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# Classification accuracy: 0.930556

# %%
############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in 
# the tangent space with a logistic regression

n_components = 2  # pick some components

# set up sklearn pipeline
clf = make_pipeline(XdawnCovariances(n_components),
                    TangentSpace(metric='riemann'),
                    LogisticRegression())

preds_rg     = np.zeros(len(Y_test))

# reshape back to (trials, channels, samples)
X_train      = X_train.reshape(X_train.shape[0], chans, samples)
X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# labels need to be back in single-column format
clf.fit(X_train, Y_train.argmax(axis = -1))
preds_rg     = clf.predict(X_test)

# Printing the results
acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
print("Classification accuracy: %f " % (acc2))

# plot the confusion matrices for both classifiers
names        = ['audio left', 'audio right', 'vis left', 'vis right']
plt.figure(0)
plot_confusion_matrix(preds, Y_test.argmax(axis = -1), names, title = 'EEGNet-8,2')

plt.figure(1)
plot_confusion_matrix(preds_rg, Y_test.argmax(axis = -1), names, title = 'xDAWN + RG')
# Out:
# Classification accuracy: 0.944444
# <AxesSubplot:title={'center':'xDAWN + RG'}, xlabel='Predicted label', ylabel='True label'>
