# %%
"""
 Sample script using EEGNet to classify Event-Related Potential (ERP) EEG data
 from a four-class classification task, using the sample dataset provided in
 the MNE [1, 2] package:
     https://martinos.org/mne/stable/manual/sample_dataset.html#ch-sample-data
   
 The four classes used from this dataset are:
     LA: Left-ear auditory stimulation
     RA: Right-ear auditory stimulation
     LV: Left visual field stimulation
     RV: Right visual field stimulation

 The code to process, filter and epoch the data are originally from Alexandre
 Barachant's PyRiemann [3] package, released under the BSD 3-clause. A copy of 
 the BSD 3-clause license has been provided together with this software to 
 comply with software licensing requirements. 
 
 When you first run this script, MNE will download the dataset and prompt you
 to confirm the download location (defaults to ~/mne_data). Follow the prompts
 to continue. The dataset size is approx. 1.5GB download. 
 
 For comparative purposes you can also compare EEGNet performance to using 
 Riemannian geometric approaches with xDAWN spatial filtering [4-8] using 
 PyRiemann (code provided below).

 [1] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck,
     L. Parkkonen, M. Hämäläinen, MNE software for processing MEG and EEG data, 
     NeuroImage, Volume 86, 1 February 2014, Pages 446-460, ISSN 1053-8119.

 [2] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck, 
     R. Goj, M. Jas, T. Brooks, L. Parkkonen, M. Hämäläinen, MEG and EEG data 
     analysis with MNE-Python, Frontiers in Neuroscience, Volume 7, 2013.

 [3] https://github.com/alexandrebarachant/pyRiemann. 

 [4] A. Barachant, M. Congedo ,"A Plug&Play P300 BCI Using Information Geometry"
     arXiv:1409.0107. link

 [5] M. Congedo, A. Barachant, A. Andreev ,"A New generation of Brain-Computer 
     Interface Based on Riemannian Geometry", arXiv: 1310.8115.

 [6] A. Barachant and S. Bonnet, "Channel selection procedure using riemannian 
     distance for BCI applications," in 2011 5th International IEEE/EMBS 
     Conference on Neural Engineering (NER), 2011, 348-351.

 [7] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Multiclass 
     Brain-Computer Interface Classification by Riemannian Geometry,” in IEEE 
     Transactions on Biomedical Engineering, vol. 59, no. 4, p. 920-928, 2012.

 [8] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Classification of 
     covariance matrices using a Riemannian-based kernel for BCI applications“, 
     in NeuroComputing, vol. 112, p. 172-178, 2013.


 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""

# %%
import PyQt5
# %config InlineBackend.figure_format = 'retina'
# %matplotlib qt5

import numpy as np

# mne imports
# import mne
# from mne import io
# from mne.datasets import sample

# EEGNet-specific imports
from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from pyriemann.utils.viz import plot_confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

# %%
def loadmeta():
    """Load meta data for analysis of PD data.

    Returns
    -------
    Fs : float
        Sampling rate (Hz)
    t : numpy array
        time array corresponding to the eeg signals
    S : int
        Number of PD patients
    Sc : int
        Number of control subjects
    flo : 2-element tuple
        frequency limits of the beta range (Hz)
    fhi : 2-element tuple
        frequency limits for the high gamma range (Hz)
    """

    Fs = 500  # Sampling rate (Hz)
    t = np.arange(0, 30, 1 / Fs)  # Time series (seconds)
    S = 270 #540 #324 #1526
    Sc = 270 #540 #324 #1509
    Smed = 270 #540 #324 #1516
    flo = (13,30)
    fhi = (50, 150)
    return Fs, t, S, Sc, Smed, flo, fhi

# %%
def _blankeeg(dtype=object):
    Fs, t, S, Sc, Smed, flo, fhi = loadmeta()
    eeg = {}
    eeg['off'] = np.zeros(S, dtype=dtype)
    eeg['on'] = np.zeros(Smed, dtype=dtype)
    eeg['C'] = np.zeros(Sc, dtype=dtype)
    return eeg

# %%
def loadPD():
    '''
    Load the data after following preprocessing:
    1. Average referenced
    
    Load rejection indices:
    1. Each index in an array

    Parameters
    ----------
    filepath : string
        path to averaged referenced data
    filepathrej : string
        path to rejection indices
        
    Returns
    -------
    eeg : dict
        Pre-processed voltage traces
        'off' : subject-by-time array for PD patients OFF medication
        'on' : subject-by-time array for PD patients ON medication        
        'C' : subject-by-time array for control subjects
        
    rejects : dict
        rejection indices including muscle artifacts
        'off' : rejection indices for PD patients OFF medication
        'on' : rejection indices for ON medication        
        'C' : rejection indices for control subjects

    '''
  
    dirB='../../UNM_Dataset/EEGNet_data/intra-patient/off_med/'
    tempB = []
    for file in os.listdir(dirB):
        fl = dirB + file
        tempB.append(fl)
    tempB = sorted(tempB)    # class: 1     val:  -1

    dirC='../../UNM_Dataset/EEGNet_data/intra-patient/on_med/'
    tempC = []
    for file in os.listdir(dirC):
        fl = dirC + file
        tempC.append(fl)
    tempC = sorted(tempC)   # class:2       val: 0

    dirE='../../UNM_Dataset/EEGNet_data/intra-patient/control/'
    tempE = []
    for file in os.listdir(dirE):
        fl = dirE + file
        tempE.append(fl)
    tempE = sorted(tempE)   # class: 3        val: 1

    eeg = _blankeeg()
#     print(len(tempB))
    for i in range(len(tempB)):
        data=io.loadmat(tempB[i], struct_as_record=False, squeeze_me=True)
        eeg['off'][i] = data['newdataMat']
        
    for i in range(len(tempC)):
        data=io.loadmat(tempC[i], struct_as_record=False, squeeze_me=True)
        eeg['on'][i] = data['newdataMat']
        
    for i in range(len(tempE)):
        data=io.loadmat(tempE[i], struct_as_record=False, squeeze_me=True)
        eeg['C'][i] = data['newdataMat']

    Fs, t, S, Sc, Smed, flo, fhi = loadmeta()
    rejects = _blankeeg()    
    rejects['off'] = np.zeros(S, dtype=int)
    rejects['on'] = np.zeros(Smed, dtype=int)
    rejects['C'] = np.zeros(Sc, dtype=int)
    
    return eeg,rejects

# %%
from __future__ import division
import numpy as np
import scipy as sp
from scipy import io
from scipy import signal
import os

# %%
Fs, t, S, Sc, Smed, flo, fhi = loadmeta() 
eeg,rejects = loadPD() # EO means Eyes Opened

# %%
cl_B    = np.ones((1,S))
cl_C    = np.full((1,Smed),3)
cl_E    = np.full((1,Sc),2)

# %%
def make_dataset(signals, subjects, channels, samples):
    dataset = np.zeros((subjects,channels,samples))
    for i in range(len(signals)):
        dataset[i,:,:] = signals[i]
    return dataset

# %%
kernels, chans, samples = 1, 60, 2900

X_off = make_dataset(eeg['off'],S,chans,samples)
X_ctl = make_dataset(eeg['on'],Smed,chans,samples)

X = np.concatenate([X_off, X_ctl], axis=0)
y = np.ravel(np.concatenate([cl_B, cl_E], axis = 0))

# %%
##################### Process, filter and epoch the data ######################

# take 50/25/25 percent of the data to train/validate/test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.5, random_state=156156)
X_test, X_validate, Y_test, Y_validate = train_test_split(X_test, Y_test, test_size=0.5, random_state=42)

# %%
############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 2, Chans = chans, Samples = samples, 
               dropoutRate = 0.5, kernLength = 16, F1 = 8, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='checkpoint.h5', verbose=1,
                               save_best_only=True)
# Out:
# X_train shape: (270, 60, 2900, 1)
# 270 train samples
# 135 test samples

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 60, 2900, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 60, 2900, 8)       128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 2900, 8)       32
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 1, 2900, 16)       960
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1, 2900, 16)       64
# _________________________________________________________________
# activation (Activation)      (None, 1, 2900, 16)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 725, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 725, 16)        0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 1, 725, 16)        512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 725, 16)        64
# _________________________________________________________________
# activation_1 (Activation)    (None, 1, 725, 16)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1, 90, 16)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 90, 16)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1440)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 2882
# _________________________________________________________________
# softmax (Activation)         (None, 2)                 0
# =================================================================
# Total params: 4,642
# Trainable params: 4,562
# Non-trainable params: 80
# _________________________________________________________________

# %%
###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

# %%
################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 32, epochs = 100, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer])

# load optimal weights
model.load_weights('checkpoint.h5')
# Out:
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0310s vs `on_train_batch_end` time: 0.0570s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.69274, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.7077 - accuracy: 0.5111 - val_loss: 0.6927 - val_accuracy: 0.4667
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.69274 to 0.68396, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.6534 - accuracy: 0.6519 - val_loss: 0.6840 - val_accuracy: 0.4741
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve from 0.68396
# 9/9 - 1s - loss: 0.6435 - accuracy: 0.6333 - val_loss: 0.6866 - val_accuracy: 0.5111
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 0.68396
# 9/9 - 1s - loss: 0.6031 - accuracy: 0.7630 - val_loss: 0.6897 - val_accuracy: 0.5185
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.68396 to 0.68008, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.5847 - accuracy: 0.7704 - val_loss: 0.6801 - val_accuracy: 0.5556
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.68008 to 0.67682, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.5646 - accuracy: 0.7444 - val_loss: 0.6768 - val_accuracy: 0.5704
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.67682 to 0.67648, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.5301 - accuracy: 0.8037 - val_loss: 0.6765 - val_accuracy: 0.5407
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.67648
# 9/9 - 1s - loss: 0.4952 - accuracy: 0.8148 - val_loss: 0.6776 - val_accuracy: 0.5481
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.67648
# 9/9 - 1s - loss: 0.4883 - accuracy: 0.8370 - val_loss: 0.6766 - val_accuracy: 0.4963
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.67648 to 0.67229, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.4744 - accuracy: 0.8222 - val_loss: 0.6723 - val_accuracy: 0.5259
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.67229 to 0.66742, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.4587 - accuracy: 0.8259 - val_loss: 0.6674 - val_accuracy: 0.5259
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.66742 to 0.66324, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.4377 - accuracy: 0.8704 - val_loss: 0.6632 - val_accuracy: 0.5037
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.66324 to 0.65978, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.4261 - accuracy: 0.8593 - val_loss: 0.6598 - val_accuracy: 0.5333
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.65978 to 0.65714, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.4002 - accuracy: 0.8630 - val_loss: 0.6571 - val_accuracy: 0.5333
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.65714 to 0.65343, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.3930 - accuracy: 0.8778 - val_loss: 0.6534 - val_accuracy: 0.5481
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.65343
# 9/9 - 1s - loss: 0.3837 - accuracy: 0.8815 - val_loss: 0.6579 - val_accuracy: 0.5185
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.65343
# 9/9 - 1s - loss: 0.3805 - accuracy: 0.8704 - val_loss: 0.6578 - val_accuracy: 0.5407
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.65343 to 0.63812, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.3790 - accuracy: 0.8815 - val_loss: 0.6381 - val_accuracy: 0.5852
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.63812
# 9/9 - 1s - loss: 0.3532 - accuracy: 0.9000 - val_loss: 0.6434 - val_accuracy: 0.5630
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.63812
# 9/9 - 1s - loss: 0.3249 - accuracy: 0.9000 - val_loss: 0.6443 - val_accuracy: 0.5630
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.63812
# 9/9 - 1s - loss: 0.3007 - accuracy: 0.9111 - val_loss: 0.6556 - val_accuracy: 0.5704
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.63812
# 9/9 - 1s - loss: 0.3001 - accuracy: 0.8963 - val_loss: 0.6412 - val_accuracy: 0.6000
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.63812
# 9/9 - 1s - loss: 0.2939 - accuracy: 0.9037 - val_loss: 0.6534 - val_accuracy: 0.5852
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.63812
# 9/9 - 1s - loss: 0.2713 - accuracy: 0.9296 - val_loss: 0.6624 - val_accuracy: 0.5852
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.63812 to 0.63423, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.2505 - accuracy: 0.9259 - val_loss: 0.6342 - val_accuracy: 0.5852
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.63423 to 0.63184, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.2414 - accuracy: 0.9444 - val_loss: 0.6318 - val_accuracy: 0.6000
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.63184 to 0.61647, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.2398 - accuracy: 0.9370 - val_loss: 0.6165 - val_accuracy: 0.6148
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.61647 to 0.60825, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.2261 - accuracy: 0.9481 - val_loss: 0.6082 - val_accuracy: 0.6370
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.60825 to 0.57905, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.2061 - accuracy: 0.9519 - val_loss: 0.5791 - val_accuracy: 0.6519
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.57905 to 0.54787, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.2057 - accuracy: 0.9519 - val_loss: 0.5479 - val_accuracy: 0.6667
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.54787
# 9/9 - 1s - loss: 0.1939 - accuracy: 0.9704 - val_loss: 0.5597 - val_accuracy: 0.6667
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.54787
# 9/9 - 1s - loss: 0.2027 - accuracy: 0.9370 - val_loss: 0.5582 - val_accuracy: 0.6815
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.54787 to 0.50768, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.1893 - accuracy: 0.9519 - val_loss: 0.5077 - val_accuracy: 0.7111
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.50768
# 9/9 - 1s - loss: 0.1906 - accuracy: 0.9519 - val_loss: 0.5455 - val_accuracy: 0.6741
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.50768 to 0.50422, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.1715 - accuracy: 0.9704 - val_loss: 0.5042 - val_accuracy: 0.6963
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.50422 to 0.45816, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.1465 - accuracy: 0.9815 - val_loss: 0.4582 - val_accuracy: 0.7333
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.45816 to 0.43452, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.1439 - accuracy: 0.9778 - val_loss: 0.4345 - val_accuracy: 0.7481
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.43452
# 9/9 - 1s - loss: 0.1416 - accuracy: 0.9778 - val_loss: 0.4588 - val_accuracy: 0.7259
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.43452 to 0.39226, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.1369 - accuracy: 0.9778 - val_loss: 0.3923 - val_accuracy: 0.8148
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.39226 to 0.37704, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.1289 - accuracy: 0.9741 - val_loss: 0.3770 - val_accuracy: 0.8296
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.37704
# 9/9 - 1s - loss: 0.1146 - accuracy: 0.9852 - val_loss: 0.3797 - val_accuracy: 0.8074
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.37704
# 9/9 - 1s - loss: 0.1141 - accuracy: 0.9778 - val_loss: 0.3878 - val_accuracy: 0.8296
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.37704
# 9/9 - 1s - loss: 0.1253 - accuracy: 0.9778 - val_loss: 0.3971 - val_accuracy: 0.7926
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.37704
# 9/9 - 1s - loss: 0.1005 - accuracy: 0.9852 - val_loss: 0.4041 - val_accuracy: 0.7704
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 0.37704 to 0.35045, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.1121 - accuracy: 0.9704 - val_loss: 0.3504 - val_accuracy: 0.8222
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.35045
# 9/9 - 1s - loss: 0.1000 - accuracy: 0.9889 - val_loss: 0.3629 - val_accuracy: 0.8000
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.35045 to 0.34660, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0987 - accuracy: 0.9778 - val_loss: 0.3466 - val_accuracy: 0.8370
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.34660 to 0.33407, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0965 - accuracy: 0.9815 - val_loss: 0.3341 - val_accuracy: 0.8519
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 0.33407 to 0.31532, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0803 - accuracy: 0.9963 - val_loss: 0.3153 - val_accuracy: 0.8889
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.31532
# 9/9 - 1s - loss: 0.0955 - accuracy: 0.9741 - val_loss: 0.3166 - val_accuracy: 0.8815
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.31532 to 0.29850, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0742 - accuracy: 0.9926 - val_loss: 0.2985 - val_accuracy: 0.8963
# Epoch 52/100
#
# Epoch 00052: val_loss improved from 0.29850 to 0.29698, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0952 - accuracy: 0.9815 - val_loss: 0.2970 - val_accuracy: 0.9037
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.29698 to 0.28474, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0693 - accuracy: 0.9889 - val_loss: 0.2847 - val_accuracy: 0.9037
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.28474
# 9/9 - 1s - loss: 0.0658 - accuracy: 0.9889 - val_loss: 0.2968 - val_accuracy: 0.9111
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.28474
# 9/9 - 1s - loss: 0.0724 - accuracy: 0.9852 - val_loss: 0.2956 - val_accuracy: 0.8889
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.28474
# 9/9 - 1s - loss: 0.0572 - accuracy: 1.0000 - val_loss: 0.3011 - val_accuracy: 0.9037
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 0.28474 to 0.28273, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.8963
# Epoch 58/100
#
# Epoch 00058: val_loss improved from 0.28273 to 0.27821, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0594 - accuracy: 0.9926 - val_loss: 0.2782 - val_accuracy: 0.9037
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 0.27821 to 0.27667, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9111
# Epoch 60/100
#
# Epoch 00060: val_loss improved from 0.27667 to 0.26735, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0585 - accuracy: 0.9926 - val_loss: 0.2673 - val_accuracy: 0.9407
# Epoch 61/100
#
# Epoch 00061: val_loss improved from 0.26735 to 0.26234, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0687 - accuracy: 1.0000 - val_loss: 0.2623 - val_accuracy: 0.8963
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0503 - accuracy: 0.9963 - val_loss: 0.2701 - val_accuracy: 0.9333
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0749 - accuracy: 0.9778 - val_loss: 0.2937 - val_accuracy: 0.9259
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0875 - accuracy: 0.9852 - val_loss: 0.3119 - val_accuracy: 0.9259
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0971 - accuracy: 0.9741 - val_loss: 0.2851 - val_accuracy: 0.9259
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0519 - accuracy: 0.9926 - val_loss: 0.2992 - val_accuracy: 0.9259
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0644 - accuracy: 0.9963 - val_loss: 0.3102 - val_accuracy: 0.9259
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0747 - accuracy: 0.9889 - val_loss: 0.3094 - val_accuracy: 0.9185
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0560 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.9185
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0517 - accuracy: 0.9926 - val_loss: 0.2658 - val_accuracy: 0.9259
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0524 - accuracy: 0.9963 - val_loss: 0.2902 - val_accuracy: 0.9333
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.26234
# 9/9 - 1s - loss: 0.0626 - accuracy: 0.9926 - val_loss: 0.2937 - val_accuracy: 0.9259
# Epoch 73/100
#
# Epoch 00073: val_loss improved from 0.26234 to 0.25495, saving model to checkpoint.h5
# 9/9 - 1s - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.2549 - val_accuracy: 0.9333
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0739 - accuracy: 0.9889 - val_loss: 0.2644 - val_accuracy: 0.9407
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0755 - accuracy: 0.9889 - val_loss: 0.2836 - val_accuracy: 0.9407
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0615 - accuracy: 0.9926 - val_loss: 0.3154 - val_accuracy: 0.9333
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0568 - accuracy: 0.9926 - val_loss: 0.2917 - val_accuracy: 0.9407
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0632 - accuracy: 0.9889 - val_loss: 0.2815 - val_accuracy: 0.8815
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9333
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0375 - accuracy: 0.9963 - val_loss: 0.2746 - val_accuracy: 0.9037
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0418 - accuracy: 0.9963 - val_loss: 0.2965 - val_accuracy: 0.9111
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0460 - accuracy: 0.9963 - val_loss: 0.2972 - val_accuracy: 0.9407
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0583 - accuracy: 0.9852 - val_loss: 0.2973 - val_accuracy: 0.9037
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0570 - accuracy: 0.9889 - val_loss: 0.2794 - val_accuracy: 0.9407
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0448 - accuracy: 0.9926 - val_loss: 0.2705 - val_accuracy: 0.9259
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0414 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.9333
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0375 - accuracy: 0.9963 - val_loss: 0.2854 - val_accuracy: 0.9333
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0415 - accuracy: 0.9926 - val_loss: 0.2615 - val_accuracy: 0.9333
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0479 - accuracy: 0.9926 - val_loss: 0.2813 - val_accuracy: 0.9407
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0437 - accuracy: 0.9926 - val_loss: 0.3265 - val_accuracy: 0.9259
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.2894 - val_accuracy: 0.9407
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9407
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0373 - accuracy: 0.9926 - val_loss: 0.3233 - val_accuracy: 0.9333
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.3024 - val_accuracy: 0.9407
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0344 - accuracy: 0.9963 - val_loss: 0.2917 - val_accuracy: 0.9407
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0322 - accuracy: 0.9926 - val_loss: 0.2716 - val_accuracy: 0.9185
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0424 - accuracy: 0.9852 - val_loss: 0.2733 - val_accuracy: 0.9407
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0483 - accuracy: 0.9889 - val_loss: 0.2793 - val_accuracy: 0.9481
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.9333
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.25495
# 9/9 - 1s - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.9481

# %%
###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = "EEGNet-8-2-weights.h5"
# model.load_weights(WEIGHTS_PATH)

# %%
###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# Classification accuracy: 0.940741

# %%
############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in 
# the tangent space with a logistic regression

n_components = 2  # pick some components

# set up sklearn pipeline
clf = make_pipeline(XdawnCovariances(n_components),
                    TangentSpace(metric='riemann'),
                    LogisticRegression())

preds_rg     = np.zeros(len(Y_test))

# reshape back to (trials, channels, samples)
X_train      = X_train.reshape(X_train.shape[0], chans, samples)
X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# labels need to be back in single-column format
clf.fit(X_train, Y_train.argmax(axis = -1))
preds_rg     = clf.predict(X_test)

# Printing the results
acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
print("Classification accuracy: %f " % (acc2))

# plot the confusion matrices for both classifiers
# names        = ['audio left', 'audio right', 'vis left', 'vis right']
names        = ['off', 'on']
plt.figure(0)
plot_confusion_matrix(preds, Y_test.argmax(axis = -1), names, title = 'EEGNet-8,2')

plt.figure(1)
plot_confusion_matrix(preds_rg, Y_test.argmax(axis = -1), names, title = 'xDAWN + RG')
# Out:
# Classification accuracy: 0.607407
# <AxesSubplot:title={'center':'xDAWN + RG'}, xlabel='Predicted label', ylabel='True label'>
